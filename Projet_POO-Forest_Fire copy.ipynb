# %% [markdown]
# ## Projet OOP

# %% [markdown]
# | Auteurs           |
# | -----------       |
# | KINDE Amine       |
# | EKRA Komenan      |
# | COULIBALY Ismael |

# %%
from jyquickhelper import add_notebook_menu 
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## Code

# %% [markdown]
# ### Création d'une Interface

# %%
## interface  
class InterTree:
    def update(self, has_burning_neighbor):
        """Update l'état des arbres selon les règles de propagations"""
        raise NotImplementedError # au cas où l'utilisateur essaie d'appeler les methodes directements
    def display_tree(self):
        """Return a symbol for displaying the tree on the console."""
        raise NotImplementedError

# %%
a1=InterTree()
a1.update(1) # Résulte d'une érreur car la méthode n'a pas été impémenté
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [6], line 2
#       1 a1=InterTree()
# ----> 2 a1.update(1)
#
# Cell In [5], line 5, in InterTree.update(self, has_burning_neighbor)
#       3 def update(self, has_burning_neighbor):
#       4     """Update l'etat des arbres selon les regles de propagations"""
# ----> 5     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# ### Implementation de la Classe Tree

# %% [markdown]
# __Requirements__: Implement a class "tree" containing the following attribute:
# 1. The state of the tree. It will be an integer equal to 0, 1, 2 or 3. A 0 for an empty cell, a 1 for a
# healthy tree, a 2 for a burning tree and a 3 for a burnt tree.
# We will provide methods to this class:
# 1. A constructor with a default value equal to 0.
# 2. A method that returns a symbol for displaying a tree on the console. It returns a '.' for a state
# equal to 0, a 'T" for a state equal to 1, a 'F' for a state equal to 2 and a 'B' for a state equal to3.
# 3. A method that takes as parameter a boolean indicating if there is a burning tree in the
# neighborhood. It will update the state of the tree according to the rules of propagation.

# %%
# Definir une classe "Tree" qui implémente l'interface  "InterTree"
class Tree(InterTree):
    def __init__(self,state=0):
        self.state=state # définit le state a 0
    #####
    def display_tree(self):
        """Retourne le symbole à afficher en fonction de l'etat de l'arbre"""
        if self.state == 0:
            return '.'
        elif self.state == 1:
            return 'T'
        elif self.state == 2:
            return 'F'
        elif self.state == 3:
            return 'B'
    #####
    def update(self, has_burning_neighbor):
        """Update l'etat de l'arbre  en fonction des règles de propagations"""
        if self.state == 0:
            # Case vide reste vide
            pass
        elif self.state == 1:
            # l'arbre saint prend feu
            if has_burning_neighbor:
                self.state = 2
        elif self.state == 2:
            # l'arbre en feu devient brulé
            self.state = 3
        elif self.state == 3:
            # les arbres brulés restent brulé
            pass

# %% [markdown]
# ### Implementation de la classe Foret

# %% [markdown]
# __Requirements__ : Implement a class "forest" containing the following attributes:
# 1. The number of rows of the grid.
# 2. The number of columns of the grid.
# 3. A two-dimensional list of objects of the class "tree" representing the grid.
# We will provide methods to this class:
# 1. A constructor that takes as extra parameter a probability value in order to initialize the grid.
# 2. A method that displays the grid on the console.
# 3. A method that takes as parameter the coordinates of a cell of the grid and that returns True if
# that cell has a burning tree in its neighborhood and False otherwise.
# 4. A method that updates the grid according to the rules of propagation. Hint: you can use the
# function ""deepcopy" of the module "copy" to do that.
# 5. A method that returns the proportion of trees in the current state of the grid.
# 6. A method that takes as parameter a strictly positive integer and that generates this number of
# generations according to the rules of propagation.

# %%
# Definir la class "Forest" contenant un cadre(grid) d'objets de types Tree
import random
from typing import List, Type
class Forest:
    def __init__(self,rows,columns,p,TreeType:Type[InterTree]=Tree):
        # Treetype est un generics de type Tree 
        self.row=rows
        self.col=columns
        """Initialiser le grid  avec des arbres sains de probabilités p et des cases vides de probabilités 1-p """
        self.grid=[[TreeType(1) if p>random.random() else TreeType(0) for i in range(self.col)] for j in range (self.row )]
        # ou
        #self.grid=[[Tree(1) if p>random.random() else Tree(0) for i in range(self.col)] for j in range (self.row )]
    #######
    def display_grid(self):
        """Méthode qui affiche le grid sur la console."""
        for row in self.grid:
            for element in row:
                print(element.display_tree(),end=' ')
            print('')
    #########
    def is_neighbor_burning(self,i,j):
        """Méthode qui prend en parametres la position d'un arbre dans la forêt et retourne Vrai ou Faux 
        selon si celui-ci à un arbre en feu comme voisin ou non  """
        for ni, nj in [(i-1,j), (i+1,j), (i,j-1), (i,j+1)]:
            # Vérifie que le voisin est bien dans la forêt 
            if 0 <= ni < len(self.grid) and 0 <= nj < len(self.grid[0]):
                if self.grid[ni][nj].state == 2:
                    return True
        return False
    ##### 

    def update_grid(self):
        """Methode qui mets à jour la forêt en fonction des règles de propagations """
        pos=[]
        # on stocke les positions des arbres qui vont changer   
        for i in range(self.row):
            for j in range(self.col):
                if self.is_neighbor_burning(i,j): # Verifie q'un arbre brule dans son voisinage 
                    pos.append((i,j))
        for a in pos: 
            self.grid[a[0]][a[1]].update(1)
    #####
    def display_tree_prop(self):
        """Méthode qui calcule la proportion d'arbres dans la forêt """
        trees=[]
        sum=0
        for i in range(self.row):
            for j in range(self.col):
                trees.append(self.grid[i][j])
        for i in trees :
            if i.state==1:
                sum+=1
        return sum/len(trees)

    def start_propagation(self,n):
        """ Méthode qui lance la propagation et l'arrête si la proportion d'arbres ne change pas """
        props=0
        new_props=1
        if (n<0) | (type(n)!=int):
            print(" Please enter a positive Integer number ")
        else:
            print("generation 1 :")
            self.display_grid()
            print(f'Tree Proportions : {int(self.display_tree_prop()*100)}%')
            print(' ')
            print("*"*50)
            for i in range(1,n):
                if props != new_props:
                    props=self.display_tree_prop()
                    print(f'generation {i+1} :')
                    self.update_grid()
                    self.display_grid()
                    print(' ')
                    print(f'Tree Proportions : {int(self.display_tree_prop()*100)}%')
                    print(' ')
                    print("*"*50)
                    new_props=self.display_tree_prop()
                else :
                    print(' No more Propagation All trees are burnt ')
                    break           
    def set_fire(self):
        """ Methode qui Met feu a un arbre aléatoirement """
        x=random.randint(0,self.row-1)
        y=random.randint(0,self.col-1)
        self.grid[x][y].state=2
        self.display_grid()

# %% [markdown]
# ### Définit une classe Toric Forest où les arbres a droites ont un voisin a gauche et ceux en bas un voisin en haut

# %%
class ToricForest(Forest):
    def is_neighbor_burning(self,x,y):#ovveride la methode 
        left,right,up,down=0,0,0,0
        try :
            if (x not in(range(self.row) )) | (y not in range(self.col)):
                raise Exception
        except :
            print("Enter valid coordinates between {0} and {1}".format(self.col-1,self.row-1))
        try:
            left=self.grid[x-1][y].state==2
        except :
            pass
        try: 
            right=self.grid[x+1][y].state==2
        except :
            pass
        try :
            up=self.grid[x][y+1].state==2
        except :
            pass
        try:
            down=self.grid[x][y-1].state==2
        except :
                pass
        return any([left,up,right,down])

# %% [markdown]
# ## Test

# %% [markdown]
# ### Test de la propagation normale

# %%
def animate(row,col,proba,n_iter):
    """Fonction  qui lance la propagation et qui prend en parametres 
    x: le nombre de lignes de la forêt
    y: le nombre de colonnes
    proba: la probabilité qu'un arbre saint pousse dans la forêt
    n_iter: Nombre d'iteration lors de la propagation"""
    object=Forest(row,col,proba)
    print('Forêt Initiale :')
    object.set_fire()
    object.start_propagation(n_iter)

# %%
animate(20,20,0.8,50)
# Out:
# Forêt Initiale :
# T T T T T . T T . T T T T T T T T T T .
# T T T T T . . . T T T T T . . T T T T T
# T T T T . T T T T T T . F T . T T T T T
# T T T . T T T T T . . T . T . T T T T T
# T T T T T T T . T T T T T T T . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# generation 1 :
# T T T T T . T T . T T T T T T T T T T .
# T T T T T . . . T T T T T . . T T T T T
# T T T T . T T T T T T . F T . T T T T T
# T T T . T T T T T . . T . T . T T T T T
# T T T T T T T . T T T T T T T . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 77%
#
# **************************************************
# generation 2 :
# T T T T T . T T . T T T T T T T T T T .
# T T T T T . . . T T T T F . . T T T T T
# T T T T . T T T T T T . F F . T T T T T
# T T T . T T T T T . . T . T . T T T T T
# T T T T T T T . T T T T T T T . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 77%
#
# **************************************************
# generation 3 :
# T T T T T . T T . T T T F T T T T T T .
# T T T T T . . . T T T F B . . T T T T T
# T T T T . T T T T T T . B B . T T T T T
# T T T . T T T T T . . T . F . T T T T T
# T T T T T T T . T T T T T T T . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 76%
#
# **************************************************
# generation 4 :
# T T T T T . T T . T T F F F T T T T T .
# T T T T T . . . T T F F B . . T T T T T
# T T T T . T T T T T T . B B . T T T T T
# T T T . T T T T T . . T . F . T T T T T
# T T T T T T T . T T T T T F T . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 75%
#
# **************************************************
# generation 5 :
# T T T T T . T T . T F B B B F T T T T .
# T T T T T . . . T F B B B . . T T T T T
# T T T T . T T T T T F . B B . T T T T T
# T T T . T T T T T . . T . B . T T T T T
# T T T T T T T . T T T T F B F . T T T .
# . T . T T T . T T T . . T . T T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 73%
#
# **************************************************
# generation 6 :
# T T T T T . T T . F F B B B F F T T T .
# T T T T T . . . F F B B B . . T T T T T
# T T T T . T T T T F F . B B . T T T T T
# T T T . T T T T T . . T . B . T T T T T
# T T T T T T T . T T T F F B F . T T T .
# . T . T T T . T T T . . F . F T T T T T
# T T . T T T T . T T T . T . T T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 72%
#
# **************************************************
# generation 7 :
# T T T T T . T T . B B B B B B B F T T .
# T T T T T . . . B B B B B . . F T T T T
# T T T T . T T T F B B . B B . T T T T T
# T T T . T T T T T . . F . B . T T T T T
# T T T T T T T . T T F B B B B . T T T .
# . T . T T T . T T T . . B . B F T T T T
# T T . T T T T . T T T . F . F T T T T T
# . T T T . T T T T . T T T T T . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 70%
#
# **************************************************
# generation 8 :
# T T T T T . T T . B B B B B B B F F T .
# T T T T T . . . B B B B B . . F F T T T
# T T T T . T T F F B B . B B . F T T T T
# T T T . T T T T F . . F . B . T T T T T
# T T T T T T T . T F F B B B B . T T T .
# . T . T T T . T T T . . B . B F F T T T
# T T . T T T T . T T T . F . F F T T T T
# . T T T . T T T T . T T F T F . T T T T
# T T T . T . T T . . T T T T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 67%
#
# **************************************************
# generation 9 :
# T T T T T . T T . B B B B B B B B B F .
# T T T T T . . . B B B B B . . B B F T T
# T T T T . T F B B B B . B B . B F T T T
# T T T . T T T F B . . F . B . F T T T T
# T T T T T T T . F B B B B B B . F T T .
# . T . T T T . T T F . . B . B B B F T T
# T T . T T T T . T T T . B . B B F T T T
# . T T T . T T T T . T F B F B . T T T T
# T T T . T . T T . . T T F T . . T T T .
# T T T T . T T . . T T . T T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 64%
#
# **************************************************
# generation 10 :
# T T T T T . T T . B B B B B B B B B F .
# T T T T T . . . B B B B B . . B B F F T
# T T T T . F F B B B B . B B . B F F T T
# T T T . T T F F B . . F . B . F F T T T
# T T T T T T T . F B B B B B B . F F T .
# . T . T T T . T F F . . B . B B B F F T
# T T . T T T T . T F T . B . B B F F T T
# . T T T . T T T T . F F B F B . F T T T
# T T T . T . T T . . T F F F . . T T T .
# T T T T . T T . . T T . F T T T T T T .
# . . T T T T T . T T T T T T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 60%
#
# **************************************************
# generation 11 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B F
# T T T T . B B B B B B . B B . B B B F T
# T T T . T F B B B . . F . B . B B F T T
# T T T T T T F . B B B B B B B . B B F .
# . T . T T T . F B B . . B . B B B B B F
# T T . T T T T . F B F . B . B B B B F T
# . T T T . T T T T . B B B B B . B F T T
# T T T . T . T T . . F B B B . . F T T .
# T T T T . T T . . T T . B F T T T T T .
# . . T T T T T . T T T T F T . T T T T T
# T T . . . . T . T . . T T . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 56%
#
# **************************************************
# generation 12 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B F
# T T T T . B B B B B B . B B . B B B F F
# T T T . F F B B B . . F . B . B B F F T
# T T T T T F F . B B B B B B B . B B F .
# . T . T T T . F B B . . B . B B B B B F
# T T . T T T T . F B F . B . B B B B F F
# . T T T . T T T F . B B B B B . B F F T
# T T T . T . T T . . F B B B . . F F T .
# T T T T . T T . . T F . B F F T F T T .
# . . T T T T T . T T T F F F . T T T T T
# T T . . . . T . T . . T F . T T T T T T
# T . T T T . T . T T T . T T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 52%
#
# **************************************************
# generation 13 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B B
# T T T T . B B B B B B . B B . B B B B B
# T T T . B B B B B . . F . B . B B B B F
# T T T T F B B . B B B B B B B . B B B .
# . T . T T F . F B B . . B . B B B B B B
# T T . T T T T . B B F . B . B B B B B B
# . T T T . T T F B . B B B B B . B B B F
# T T T . T . T T . . B B B B . . B B F .
# T T T T . T T . . F B . B B B F B F T .
# . . T T T T T . T T F B B B . T F T T T
# T T . . . . T . T . . F B . T T T T T T
# T . T T T . T . T T T . F T T T . T T T
# T T T T T T T T T T T . T T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 49%
#
# **************************************************
# generation 14 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B B
# T T T T . B B B B B B . B B . B B B B B
# T T T . B B B B B . . F . B . B B B B F
# T T T F F B B . B B B B B B B . B B B .
# . T . T F F . F B B . . B . B B B B B B
# T T . T T F T . B B F . B . B B B B B B
# . T T T . T F F B . B B B B B . B B B F
# T T T . T . T F . . B B B B . . B B F .
# T T T T . T T . . F B . B B B F B F F .
# . . T T T T T . T F F B B B . F F F T T
# T T . . . . T . T . . F B . T T F T T T
# T . T T T . T . T T T . F F T T . T T T
# T T T T T T T T T T T . F T T T T . T T
# T T T T T T . T . T T T T T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 46%
#
# **************************************************
# generation 15 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B B
# T T T T . B B B B B B . B B . B B B B B
# T T T . B B B B B . . F . B . B B B B F
# T T F B B B B . B B B B B B B . B B B .
# . T . F B B . F B B . . B . B B B B B B
# T T . T F B F . B B F . B . B B B B B B
# . T T T . F B B B . B B B B B . B B B F
# T T T . T . F B . . B B B B . . B B B .
# T T T T . T T . . B B . B B B B B B B .
# . . T T T T T . F B B B B B . B B B F T
# T T . . . . T . T . . F B . T F B F T T
# T . T T T . T . T T T . B B F T . T T T
# T T T T T T T T T T T . B F T T T . T T
# T T T T T T . T . T T T F T T T T T T .
# T . T T T T T . . T T T T T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 43%
#
# **************************************************
# generation 16 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B B
# T T T T . B B B B B B . B B . B B B B B
# T T F . B B B B B . . F . B . B B B B F
# T F F B B B B . B B B B B B B . B B B .
# . T . F B B . F B B . . B . B B B B B B
# T T . F F B F . B B F . B . B B B B B B
# . T T T . F B B B . B B B B B . B B B F
# T T T . T . F B . . B B B B . . B B B .
# T T T T . T F . . B B . B B B B B B B .
# . . T T T T T . F B B B B B . B B B F F
# T T . . . . T . F . . F B . F F B F F T
# T . T T T . T . T T T . B B F F . F T T
# T T T T T T T T T T T . B F F T T . T T
# T T T T T T . T . T T F F F T T T T T .
# T . T T T T T . . T T T F T T T T T T T
# . . T T T T T . T T . T T T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 39%
#
# **************************************************
# generation 17 :
# T T T T T . T T . B B B B B B B B B B .
# T T T T T . . . B B B B B . . B B B B B
# T T F T . B B B B B B . B B . B B B B B
# T F B . B B B B B . . F . B . B B B B F
# F B B B B B B . B B B B B B B . B B B .
# . F . B B B . F B B . . B . B B B B B B
# T T . B B B F . B B F . B . B B B B B B
# . T T F . F B B B . B B B B B . B B B F
# T T T . T . B B . . B B B B . . B B B .
# T T T T . F B . . B B . B B B B B B B .
# . . T T T T F . B B B B B B . B B B B B
# T T . . . . T . B . . F B . B B B B B F
# T . T T T . T . F T T . B B B B . B F T
# T T T T T T T T T T T . B B B F T . T T
# T T T T T T . T . T F B B B F T T T T .
# T . T T T T T . . T T F B F T T T T T T
# . . T T T T T . T T . T F T T . T T T .
# T T . T T . T T T T T T T T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 35%
#
# **************************************************
# generation 18 :
# T T T T T . T T . B B B B B B B B B B .
# T T F T T . . . B B B B B . . B B B B B
# T F F F . B B B B B B . B B . B B B B B
# F F B . B B B B B . . F . B . B B B B F
# F B B B B B B . B B B B B B B . B B B .
# . F . B B B . F B B . . B . B B B B B B
# T F . B B B F . B B F . B . B B B B B B
# . T F F . F B B B . B B B B B . B B B F
# T T T . T . B B . . B B B B . . B B B .
# T T T T . F B . . B B . B B B B B B B .
# . . T T T F F . B B B B B B . B B B B B
# T T . . . . F . B . . F B . B B B B B F
# T . T T T . T . F F T . B B B B . B F F
# T T T T T T T T F T F . B B B F F . F T
# T T T T T T . T . F F B B B F F T T T .
# T . T T T T T . . T F F B F F T T T T T
# . . T T T T T . T T . F F F T . T T T .
# T T . T T . T T T T T T F T T T T T . .
# T . T T T . . T T T T T T T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 30%
#
# **************************************************
# generation 19 :
# T T F T T . T T . B B B B B B B B B B .
# T F B F T . . . B B B B B . . B B B B B
# F B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . F B B . F B B B . B B B B B . B B B F
# T T F . T . B B . . B B B B . . B B B .
# T T T T . B B . . B B . B B B B B B B .
# . . T T F B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T T T . F . B B F . B B B B . B B B
# T T T T T T T F B F B . B B B B B . B F
# T T T T T T . T . B B B B B B B F T F .
# T . T T T T T . . F B B B B B F T T T T
# . . T T T T T . T T . B B B F . T T T .
# T T . T T . T T T T T F B F T T T T . .
# T . T T T . . T T T T T F T T T T T . .
# T T . . T T T . T T T T T T T T T . T T
# Tree Proportions : 25%
#
# **************************************************
# generation 20 :
# T F F F T . T T . B B B B B B B B B B .
# F F B F F . . . B B B B B . . B B B B B
# F B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . F B B . F B B B . B B B B B . B B B F
# T F F . T . B B . . B B B B . . B B B .
# T T F T . B B . . B B . B B B B B B B .
# . . T F F B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T T T . F . B B F . B B B B . B B B
# T T T T T T F F B F B . B B B B B . B F
# T T T T T T . F . B B B B B B B F F F .
# T . T T T T T . . F B B B B B F F T F T
# . . T T T T T . T F . B B B F . T T T .
# T T . T T . T T T T F F B F F T T T . .
# T . T T T . . T T T T F F F T T T T . .
# T T . . T T T . T T T T F T T T T . T T
# Tree Proportions : 20%
#
# **************************************************
# generation 21 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# F B B . T . B B . . B B B B . . B B B .
# T F B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T T T . B . B B F . B B B B . B B B
# T T T T T F B B B F B . B B B B B . B F
# T T T T T T . B . B B B B B B B B B B .
# T . T T T T T . . B B B B B B B B F B F
# . . T T T T T . F B . B B B B . F T F .
# T T . T T . T T T F B B B B B F T T . .
# T . T T T . . T T T F B B B F T T T . .
# T T . . T T T . T T T F B F T T T . T T
# Tree Proportions : 16%
#
# **************************************************
# generation 22 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# F B B . T . B B . . B B B B . . B B B .
# F F B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T T T . B . B B F . B B B B . B B B
# T T T T F F B B B F B . B B B B B . B F
# T T T T T F . B . B B B B B B B B B B .
# T . T T T T T . . B B B B B B B B F B F
# . . T T T T T . F B . B B B B . F F F .
# T T . T T . T T F F B B B B B F F T . .
# T . T T T . . T T F F B B B F F T T . .
# T T . . T T T . T T F F B F F T T . T T
# Tree Proportions : 13%
#
# **************************************************
# generation 23 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T T F . B . B B F . B B B B . B B B
# T T T F B B B B B F B . B B B B B . B F
# T T T T F B . B . B B B B B B B B B B .
# T . T T T F T . . B B B B B B B B B B F
# . . T T T T T . B B . B B B B . B B B .
# T T . T T . T F B B B B B B B B B F . .
# T . T T T . . T F B B B B B B B F T . .
# T T . . T T T . T F B B B B B F T . T T
# Tree Proportions : 11%
#
# **************************************************
# generation 24 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . T F F . B . B B F . B B B B . B B B
# T T F F B B B B B F B . B B B B B . B F
# T T T F F B . B . B B B B B B B B B B .
# T . T T F F F . . B B B B B B B B B B F
# . . T T T F T . B B . B B B B . B B B .
# T T . T T . F F B B B B B B B B B F . .
# T . T T T . . F F B B B B B B B F F . .
# T T . . T T T . F F B B B B B F F . T T
# Tree Proportions : 8%
#
# **************************************************
# generation 25 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . F B B . B . B B F . B B B B . B B B
# T F B B B B B B B F B . B B B B B . B F
# T T F B B B . B . B B B B B B B B B B .
# T . T F B B B . . B B B B B B B B B B F
# . . T T F B F . B B . B B B B . B B B .
# T T . T T . B B B B B B B B B B B B . .
# T . T T T . . B B B B B B B B B B B . .
# T T . . T T T . B B B B B B B B B . T T
# Tree Proportions : 7%
#
# **************************************************
# generation 26 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# T . F B B . B . B B F . B B B B . B B B
# F F B B B B B B B F B . B B B B B . B F
# T F F B B B . B . B B B B B B B B B B .
# T . F F B B B . . B B B B B B B B B B F
# . . T F F B F . B B . B B B B . B B B .
# T T . T F . B B B B B B B B B B B B . .
# T . T T T . . B B B B B B B B B B B . .
# T T . . T T T . B B B B B B B B B . T T
# Tree Proportions : 5%
#
# **************************************************
# generation 27 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# T T . . . . B . B . . F B . B B B B B B
# F . F B B . B . B B F . B B B B . B B B
# B B B B B B B B B F B . B B B B B . B F
# F B B B B B . B . B B B B B B B B B B .
# T . B B B B B . . B B B B B B B B B B F
# . . F B B B F . B B . B B B B . B B B .
# T T . F B . B B B B B B B B B B B B . .
# T . T T F . . B B B B B B B B B B B . .
# T T . . T T T . B B B B B B B B B . T T
# Tree Proportions : 4%
#
# **************************************************
# generation 28 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# F T . . . . B . B . . F B . B B B B B B
# F . F B B . B . B B F . B B B B . B B B
# B B B B B B B B B F B . B B B B B . B F
# F B B B B B . B . B B B B B B B B B B .
# F . B B B B B . . B B B B B B B B B B F
# . . F B B B F . B B . B B B B . B B B .
# T T . F B . B B B B B B B B B B B B . .
# T . T F F . . B B B B B B B B B B B . .
# T T . . F T T . B B B B B B B B B . T T
# Tree Proportions : 3%
#
# **************************************************
# generation 29 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# B F . . . . B . B . . F B . B B B B B B
# B . F B B . B . B B F . B B B B . B B B
# B B B B B B B B B F B . B B B B B . B F
# B B B B B B . B . B B B B B B B B B B .
# B . B B B B B . . B B B B B B B B B B F
# . . F B B B F . B B . B B B B . B B B .
# T T . B B . B B B B B B B B B B B B . .
# T . F B B . . B B B B B B B B B B B . .
# T T . . B F T . B B B B B B B B B . T T
# Tree Proportions : 2%
#
# **************************************************
# generation 30 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# B F . . . . B . B . . F B . B B B B B B
# B . F B B . B . B B F . B B B B . B B B
# B B B B B B B B B F B . B B B B B . B F
# B B B B B B . B . B B B B B B B B B B .
# B . B B B B B . . B B B B B B B B B B F
# . . F B B B F . B B . B B B B . B B B .
# T T . B B . B B B B B B B B B B B B . .
# T . F B B . . B B B B B B B B B B B . .
# T T . . B F F . B B B B B B B B B . T T
# Tree Proportions : 2%
#
# **************************************************
# generation 31 :
# F B B B F . T T . B B B B B B B B B B .
# B B B B B . . . B B B B B . . B B B B B
# B B B B . B B B B B B . B B . B B B B B
# B B B . B B B B B . . F . B . B B B B F
# B B B B B B B . B B B B B B B . B B B .
# . B . B B B . F B B . . B . B B B B B B
# F B . B B B F . B B F . B . B B B B B B
# . B B B . F B B B . B B B B B . B B B F
# B B B . T . B B . . B B B B . . B B B .
# B B B F . B B . . B B . B B B B B B B .
# . . F B B B B . B B B B B B . B B B B B
# B F . . . . B . B . . F B . B B B B B B
# B . F B B . B . B B F . B B B B . B B B
# B B B B B B B B B F B . B B B B B . B F
# B B B B B B . B . B B B B B B B B B B .
# B . B B B B B . . B B B B B B B B B B F
# . . F B B B F . B B . B B B B . B B B .
# T T . B B . B B B B B B B B B B B B . .
# T . F B B . . B B B B B B B B B B B . .
# T T . . B B B . B B B B B B B B B . T T
# Tree Proportions : 2%
#
# **************************************************
#  No more Propagation All trees are burnt

# %% [markdown]
# ### Test de propagation de la forêt Toric

# %%
def animate_toric(row,col,proba,n_iter):
    """Fonction  qui lance la propagation et qui prend en parametres 
    x: le nombre de lignes de la forêt
    y: le nombre de colonnes
    proba: la probabilité qu'un arbre saint pousse dans la forêt
    n_iter: Nombre d'iteration lors de la propagation"""
    object=ToricForest(row,col,proba)
    print('Forêt Initiale :')
    object.set_fire()
    object.start_propagation(n_iter)

# %%
animate_toric(20,20,0.8,50)
# Out:
# Forêt Initiale :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T T T . T T T T T T
# T T T . T T T T . T T T T T T T . T T T
# T T . T T T T . T T T T . T T . T T T .
# T T T . . T . T T T T T T T T T T . T T
# . . T T T T T T T T T F T T T T T T T T
# . . . . T T T T T T . T T . T T . T T T
# T T T T T T T . T T . T T . . T T T T T
# T T T . T T . T T T T T T T . . T T T T
# T T T T . T T T T T T T . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# generation 1 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T T T . T T T T T T
# T T T . T T T T . T T T T T T T . T T T
# T T . T T T T . T T T T . T T . T T T .
# T T T . . T . T T T T T T T T T T . T T
# . . T T T T T T T T T F T T T T T T T T
# . . . . T T T T T T . T T . T T . T T T
# T T T T T T T . T T . T T . . T T T T T
# T T T . T T . T T T T T T T . . T T T T
# T T T T . T T T T T T T . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 83%
#
# **************************************************
# generation 2 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T T T . T T T T T T
# T T T . T T T T . T T T T T T T . T T T
# T T . T T T T . T T T T . T T . T T T .
# T T T . . T . T T T T F T T T T T . T T
# . . T T T T T T T T F F F T T T T T T T
# . . . . T T T T T T . F T . T T . T T T
# T T T T T T T . T T . T T . . T T T T T
# T T T . T T . T T T T T T T . . T T T T
# T T T T . T T T T T T T . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 82%
#
# **************************************************
# generation 3 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T T T . T T T T T T
# T T T . T T T T . T T T T T T T . T T T
# T T . T T T T . T T T F . T T . T T T .
# T T T . . T . T T T F B F T T T T . T T
# . . T T T T T T T F B B B F T T T T T T
# . . . . T T T T T T . B F . T T . T T T
# T T T T T T T . T T . F T . . T T T T T
# T T T . T T . T T T T T T T . . T T T T
# T T T T . T T T T T T T . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 81%
#
# **************************************************
# generation 4 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T T T . T T T T T T
# T T T . T T T T . T T F T T T T . T T T
# T T . T T T T . T T F F . T T . T T T .
# T T T . . T . T T F F B F F T T T . T T
# . . T T T T T T F F B B B F F T T T T T
# . . . . T T T T T F . B F . T T . T T T
# T T T T T T T . T T . F F . . T T T T T
# T T T . T T . T T T T F T T . . T T T T
# T T T T . T T T T T T T . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 78%
#
# **************************************************
# generation 5 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T T T T T T T T T T
# T T T T T T T T T T T F T . T T T T T T
# T T T . T T T T . T F B F T T T . T T T
# T T . T T T T . T F B B . F T . T T T .
# T T T . . T . T F B B B B B F T T . T T
# . . T T T T T F B B B B B B B F T T T T
# . . . . T T T T F B . B B . F T . T T T
# T T T T T T T . T F . B B . . T T T T T
# T T T . T T . T T T F B F T . . T T T T
# T T T T . T T T T T T F . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 75%
#
# **************************************************
# generation 6 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T T T T T T T T . T
# T T T T T T T T T T T F T T T T T T T T
# T T T T T T T T T T F F F . T T T T T T
# T T T . T T T T . F F B F F T T . T T T
# T T . T T T T . F F B B . F F . T T T .
# T T T . . T . F F B B B B B F F T . T T
# . . T T T T F F B B B B B B B F F T T T
# . . . . T T T F F B . B B . F F . T T T
# T T T T T T T . F F . B B . . T T T T T
# T T T . T T . T T F F B F F . . T T T T
# T T T T . T T T T T F F . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 70%
#
# **************************************************
# generation 7 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T T T T T . T T T T
# T T . T T T T T . T T F T T T T T T . T
# T T T T T T T T T T F B F T T T T T T T
# T T T T T T T T T F B B B . T T T T T T
# T T T . T T T T . B B B B B F T . T T T
# T T . T T T T . B B B B . B B . T T T .
# T T T . . T . B B B B B B B B B F . T T
# . . T T T F B B B B B B B B B B B F T T
# . . . . T T F B B B . B B . B B . T T T
# T T T T T T T . B B . B B . . F T T T T
# T T T . T T . T F B B B B B . . T T T T
# T T T T . T T T T F B B . . . T T T T T
# T . T . T T T . T T . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 67%
#
# **************************************************
# generation 8 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T T . . T T . T T T
# T T T T T T T T T T T F T T T . T T T T
# T T . T T T T T . T F F F T T T T T . T
# T T T T T T T T T F F B F F T T T T T T
# T T T T T T T T F F B B B . F T T T T T
# T T T . T T T T . B B B B B F F . T T T
# T T . T T T T . B B B B . B B . F T T .
# T T T . . F . B B B B B B B B B F . T T
# . . T T F F B B B B B B B B B B B F F T
# . . . . T F F B B B . B B . B B . F T T
# T T T T T T F . B B . B B . . F F T T T
# T T T . T T . F F B B B B B . . T T T T
# T T T T . T T T F F B B . . . T T T T T
# T . T . T T T . T F . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 63%
#
# **************************************************
# generation 9 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T T T T T T T T . .
# T T T T T T T T T T T F . . T T . T T T
# T T T T T T T T T T F B F T T . T T T T
# T T . T T T T T . F B B B F T T T T . T
# T T T T T T T T F B B B B B F T T T T T
# T T T T T T T F B B B B B . B F T T T T
# T T T . T T T T . B B B B B B B . T T T
# T T . T T F T . B B B B . B B . B F T .
# T T T . . B . B B B B B B B B B B . F T
# . . T F B B B B B B B B B B B B B B B F
# . . . . F B B B B B . B B . B B . B F T
# T T T T T F B . B B . B B . . B B F T T
# T T T . T T . B B B B B B B . . F T T T
# T T T T . T T F B B B B . . . T T T T T
# T . T . T T T . F B . . T T . T T T T T
# T T T T T T T T T . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 57%
#
# **************************************************
# generation 10 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T T T T . T T T T T
# T T T T T T . T . T T F T T T T T T . .
# T T T T T T T T T T F F . . T T . T T T
# T T T T T T T T T F F B F F T . T T T T
# T T . T T T T T . F B B B F F T T T . T
# T T T T T T T F F B B B B B F F T T T T
# T T T T T T F F B B B B B . B F F T T T
# T T T . T F T F . B B B B B B B . F T T
# T T . T F F F . B B B B . B B . B F F .
# T T T . . B . B B B B B B B B B B . F F
# . . F F B B B B B B B B B B B B B B B F
# . . . . F B B B B B . B B . B B . B F F
# T T T T F F B . B B . B B . . B B F F T
# T T T . T F . B B B B B B B . . F F T T
# T T T T . T F F B B B B . . . T F T T T
# T . T . T T T . F B . . T T . T T T T T
# T T T T T T T T F . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 51%
#
# **************************************************
# generation 11 :
# T T T T . T T T T T T T T T T . T T T T
# T T T T T T T T T T T F T T . T T T T T
# T T T T T T . T . T F B F T T T T T . .
# T T T T T T T T T F B B . . T T . T T T
# T T T T T T T T F B B B B B F . T T T T
# T T . T T T T F . B B B B B B F T T . T
# T T T T T T F B B B B B B B B B F T T T
# T T T T T F B B B B B B B . B B B F T T
# T T T . F B F B . B B B B B B B . B F T
# T T . F B B B . B B B B . B B . B B B .
# F T F . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# T T T F B B B . B B . B B . . B B B B F
# T T T . F B . B B B B B B B . . B B F T
# T T T T . F B B B B B B . . . F B F T T
# T . T . T T F . B B . . T T . T F T T T
# T T T T T T T F B . T T T T T T . T T .
# T . T T T T T T . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 44%
#
# **************************************************
# generation 12 :
# T T T T . T T T T T T F T T T . T T T T
# T T T T T T T T T T F F F T . T T T T T
# T T T T T T . T . F F B F F T T T T . .
# T T T T T T T T F F B B . . F T . T T T
# T T T T T T T F F B B B B B F . T T T T
# T T . T T T F F . B B B B B B F F T . T
# T T T T T F F B B B B B B B B B F F T T
# T T T T F F B B B B B B B . B B B F F T
# T T T . F B F B . B B B B B B B . B F F
# F T . F B B B . B B B B . B B . B B B .
# F F F . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# F T F F B B B . B B . B B . . B B B B F
# T T T . F B . B B B B B B B . . B B F F
# T T T T . F B B B B B B . . . F B F F T
# T . T . T F F . B B . . T T . F F F T T
# T T T T T T F F B . T T T T T T . T T .
# T . T T T T T F . T T . . T T T T T T T
# T T . T T T T T . T T T . T T T T T T T
# Tree Proportions : 38%
#
# **************************************************
# generation 13 :
# T T T T . T T T T T F B F T T . T T T T
# T T T T T T T T T F B B B F . T T T T T
# T T T T T T . T . B B B B B F T T T . .
# T T T T T T T F B B B B . . B F . T T T
# T T T T T T F B B B B B B B B . F T T T
# T T . T T F B B . B B B B B B B B F . T
# T T T T F B B B B B B B B B B B B B F T
# T T T F B B B B B B B B B . B B B B B F
# F T T . B B F B . B B B B B B B . B B B
# B F . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B F B B B B B . B B . B B . . B B B B B
# F T F . F B . B B B B B B B . . B B B B
# T T T T . B B B B B B B . . . B B B B F
# T . T . F B B . B B . . T T . B B B F T
# T T T T T F B B B . T T T T T F . F T .
# T . T T T T F B . T T . . T T T T T T T
# T T . T T T T F . T T T . T T T T T T T
# Tree Proportions : 31%
#
# **************************************************
# generation 14 :
# T T T T . T T F T F F B F F T . T T T T
# T T T T T T T T F F B B B F . T T T T T
# T T T T T T . F . B B B B B F F T T . .
# T T T T T T F F B B B B . . B F . T T T
# T T T T T F F B B B B B B B B . F F T T
# T T . T F F B B . B B B B B B B B F . T
# T T T F F B B B B B B B B B B B B B F F
# F T F F B B B B B B B B B . B B B B B F
# F F T . B B F B . B B B B B B B . B B B
# B F . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B F B B B B B . B B . B B . . B B B B B
# F F F . F B . B B B B B B B . . B B B B
# F T F T . B B B B B B B . . . B B B B F
# T . T . F B B . B B . . T T . B B B F F
# T T T T F F B B B . T T T T F F . F F .
# T . T T T F F B . T T . . T T F T F T T
# T T . T T T F F . T T T . T T T T T T T
# Tree Proportions : 24%
#
# **************************************************
# generation 15 :
# T T T T . T F B F B B B B B F . T T T T
# T T T T T T T F B B B B B B . F T T T T
# T T T T T T . B . B B B B B B B F T . .
# T T T T T F B B B B B B . . B B . F T T
# T T T T F B B B B B B B B B B . B B F T
# T T . F B B B B . B B B B B B B B B . F
# F T F B B B B B B B B B B B B B B B B B
# B F B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# F . F . B B B . B B . . T T . B B B B B
# T T T F B B B B B . T T T F B B . B B .
# T . T T F B B B . T T . . T F B F B F T
# T T . T T F B B . T T T . T T F T F T T
# Tree Proportions : 17%
#
# **************************************************
# generation 16 :
# T T T T . F F B F B B B B B F . T F T T
# T T T T T T F F B B B B B B . F F T T T
# T T T T T F . B . B B B B B B B F F . .
# T T T T F F B B B B B B . . B B . F F T
# T T T F F B B B B B B B B B B . B B F F
# F T . F B B B B . B B B B B B B B B . F
# F F F B B B B B B B B B B B B B B B B B
# B F B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# F . F . B B B . B B . . T F . B B B B B
# F T F F B B B B B . T T F F B B . B B .
# T . T F F B B B . T T . . F F B F B F F
# T T . T F F B B . T T T . T F F F F F T
# Tree Proportions : 11%
#
# **************************************************
# generation 17 :
# T T T T . B B B F B B B B B B . F B F T
# T T T T T F B B B B B B B B . B B F T T
# T T T T F B . B . B B B B B B B B B . .
# T T T F B B B B B B B B . . B B . B B F
# F T F B B B B B B B B B B B B . B B B B
# B F . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . T F B B B B . B B .
# F . F B B B B B . T T . . B B B B B B B
# T T . F B B B B . T T T . F B B B B B F
# Tree Proportions : 7%
#
# **************************************************
# generation 18 :
# T T T F . B B B F B B B B B B . F B F F
# T T T T F F B B B B B B B B . B B F F T
# T T T F F B . B . B B B B B B B B B . .
# F T F F B B B B B B B B . . B B . B B F
# F F F B B B B B B B B B B B B . B B B B
# B F . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . F F B B B B . B B .
# F . F B B B B B . T T . . B B B B B B B
# F T . F B B B B . T T T . F B B B B B F
# Tree Proportions : 4%
#
# **************************************************
# generation 19 :
# F T F B . B B B F B B B B B B . F B B B
# T T T F B B B B B B B B B B . B B B B F
# F T F B B B . B . B B B B B B B B B . .
# B F B B B B B B B B B B . . B B . B B F
# B B B B B B B B B B B B B B B . B B B B
# B B . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . B B B B B B . B B .
# B . F B B B B B . T F . . B B B B B B B
# B F . F B B B B . T T T . F B B B B B F
# Tree Proportions : 2%
#
# **************************************************
# generation 20 :
# F F F B . B B B F B B B B B B . F B B B
# F T F F B B B B B B B B B B . B B B B F
# F F F B B B . B . B B B B B B B B B . .
# B F B B B B B B B B B B . . B B . B B F
# B B B B B B B B B B B B B B B . B B B B
# B B . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . B B B B B B . B B .
# B . F B B B B B . F F . . B B B B B B B
# B F . F B B B B . T F T . F B B B B B F
# Tree Proportions : 0%
#
# **************************************************
# generation 21 :
# B B B B . B B B F B B B B B B . F B B B
# B F B B B B B B B B B B B B . B B B B F
# B B B B B B . B . B B B B B B B B B . .
# B B B B B B B B B B B B . . B B . B B F
# B B B B B B B B B B B B B B B . B B B B
# B B . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . B B B B B B . B B .
# B . F B B B B B . B B . . B B B B B B B
# B F . F B B B B . F B F . F B B B B B F
# Tree Proportions : 0%
#
# **************************************************
# generation 22 :
# B B B B . B B B F B B B B B B . F B B B
# B F B B B B B B B B B B B B . B B B B F
# B B B B B B . B . B B B B B B B B B . .
# B B B B B B B B B B B B . . B B . B B F
# B B B B B B B B B B B B B B B . B B B B
# B B . B B B B B . B B B B B B B B B . B
# B B B B B B B B B B B B B B B B B B B B
# B B B B B B B B B B B B B . B B B B B B
# B B F . B B F B . B B B B B B B . B B B
# B B . F B B B . B B B B . B B . B B B .
# B B B . . B . B B B B B B B B B B . B B
# . . B B B B B B B B B B B B B B B B B B
# . . . . B B B B B B . B B . B B . B B B
# B B B B B B B . B B . B B . . B B B B B
# B B B . F B . B B B B B B B . . B B B B
# B F B F . B B B B B B B . . . B B B B B
# B . B . B B B . B B . . F B . B B B B B
# B F B B B B B B B . B B B B B B . B B .
# B . F B B B B B . B B . . B B B B B B B
# B F . F B B B B . F B F . F B B B B B F
# Tree Proportions : 0%
#
# **************************************************
#  No more Propagation All trees are burnt
